# %%
# Data Augmentation (DA) Technique

# %%
# pip install Pillow

# %%
#Example of agumentation
from IPython.display import display
from PIL import Image


path="example.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=549x165>

# %%
# Textattack

# %%
# !pip install textattack
# Out:
# Collecting textattack
#   Using cached textattack-0.3.4-py3-none-any.whl (373 kB)
# Requirement already satisfied: nltk in /home/user/anaconda3/envs/NLP/lib/python3.8/site-packages (from textattack) (3.7)
# Collecting datasets
#   Downloading datasets-2.0.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 599 kB/s eta 0:00:01
# Collecting scipy>=1.4.1
#   Using cached scipy-1.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
# Collecting word2number
#   Using cached word2number-1.1.zip (9.7 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /home/user/anaconda3/envs/NLP/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-jp4p7fpw/word2number_5f48af50b95442a6b1c8469fa466b353/setup.py'"'"'; __file__='"'"'/tmp/pip-install-jp4p7fpw/word2number_5f48af50b95442a6b1c8469fa466b353/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-kzid9y8d
#          cwd: /tmp/pip-install-jp4p7fpw/word2number_5f48af50b95442a6b1c8469fa466b353/
#     Complete output (23 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-jp4p7fpw/word2number_5f48af50b95442a6b1c8469fa466b353/setup.py", line 12, in <module>
#         setup(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/core.py", line 108, in setup
#         _setup_distribution = dist = klass(attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 453, in __init__
#         _Distribution.__init__(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/dist.py", line 292, in __init__
#         self.finalize_options()
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 830, in finalize_options
#         for ep in sorted(loaded, key=by_order):
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 829, in <lambda>
#         loaded = map(lambda e: e.load(), filtered)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2449, in load
#         self.require(*args, **kwargs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2472, in require
#         items = working_set.resolve(reqs, env, installer, extras=self.extras)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 772, in resolve
#         raise DistributionNotFound(req, requirers)
#     pkg_resources.DistributionNotFound: The 'tomli>=1.0.0' distribution was not found and is required by the application
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/4a/29/a31940c848521f0725f0df6b25dca8917f13a2025b0e8fcbe5d0457e45e6/word2number-1.1.zip#sha256=70e27a5d387f67b04c71fbb7621c05930b19bfd26efd6851e6e0f9969dcde7d0 (from https://pypi.org/simple/word2number/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached word2number-1.0.zip (9.4 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /home/user/anaconda3/envs/NLP/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-jp4p7fpw/word2number_bacd6e73b921444eb34785fb81017737/setup.py'"'"'; __file__='"'"'/tmp/pip-install-jp4p7fpw/word2number_bacd6e73b921444eb34785fb81017737/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-z6w3enik
#          cwd: /tmp/pip-install-jp4p7fpw/word2number_bacd6e73b921444eb34785fb81017737/
#     Complete output (23 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-jp4p7fpw/word2number_bacd6e73b921444eb34785fb81017737/setup.py", line 12, in <module>
#         setup(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/core.py", line 108, in setup
#         _setup_distribution = dist = klass(attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 453, in __init__
#         _Distribution.__init__(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/dist.py", line 292, in __init__
#         self.finalize_options()
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 830, in finalize_options
#         for ep in sorted(loaded, key=by_order):
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 829, in <lambda>
#         loaded = map(lambda e: e.load(), filtered)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2449, in load
#         self.require(*args, **kwargs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2472, in require
#         items = working_set.resolve(reqs, env, installer, extras=self.extras)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 772, in resolve
#         raise DistributionNotFound(req, requirers)
#     pkg_resources.DistributionNotFound: The 'tomli>=1.0.0' distribution was not found and is required by the application
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/f4/d4/4e18534181f5727a53349043c62c8accb85b7fe613a19e0e788ae9f6ee19/word2number-1.0.zip#sha256=72770e04aa5d74fe5c87b42596d459aa4571561b9f0b6e17358ace3075aeb321 (from https://pypi.org/simple/word2number/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached word2number-0.2.zip (8.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /home/user/anaconda3/envs/NLP/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-jp4p7fpw/word2number_17565801e6134e28945dee985a496337/setup.py'"'"'; __file__='"'"'/tmp/pip-install-jp4p7fpw/word2number_17565801e6134e28945dee985a496337/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-vrpbe6x5
#          cwd: /tmp/pip-install-jp4p7fpw/word2number_17565801e6134e28945dee985a496337/
#     Complete output (23 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-jp4p7fpw/word2number_17565801e6134e28945dee985a496337/setup.py", line 12, in <module>
#         setup(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/core.py", line 108, in setup
#         _setup_distribution = dist = klass(attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 453, in __init__
#         _Distribution.__init__(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/dist.py", line 292, in __init__
#         self.finalize_options()
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 830, in finalize_options
#         for ep in sorted(loaded, key=by_order):
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 829, in <lambda>
#         loaded = map(lambda e: e.load(), filtered)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2449, in load
#         self.require(*args, **kwargs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2472, in require
#         items = working_set.resolve(reqs, env, installer, extras=self.extras)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 772, in resolve
#         raise DistributionNotFound(req, requirers)
#     pkg_resources.DistributionNotFound: The 'tomli>=1.0.0' distribution was not found and is required by the application
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a1/2a/e981d3e4ae07a7e387d89d4f493091d62ce86948a8d36ef8e04cdaddaede/word2number-0.2.zip#sha256=227ea7f5193be5cae2904955b3c76d643cc1328be2d692cb6793e7e206720b89 (from https://pypi.org/simple/word2number/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached word2number-0.1.zip (8.1 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /home/user/anaconda3/envs/NLP/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-jp4p7fpw/word2number_d8cef7adbda14f83a2d6f69153f26636/setup.py'"'"'; __file__='"'"'/tmp/pip-install-jp4p7fpw/word2number_d8cef7adbda14f83a2d6f69153f26636/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-dfjabig1
#          cwd: /tmp/pip-install-jp4p7fpw/word2number_d8cef7adbda14f83a2d6f69153f26636/
#     Complete output (23 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-jp4p7fpw/word2number_d8cef7adbda14f83a2d6f69153f26636/setup.py", line 12, in <module>
#         setup(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/core.py", line 108, in setup
#         _setup_distribution = dist = klass(attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 453, in __init__
#         _Distribution.__init__(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/dist.py", line 292, in __init__
#         self.finalize_options()
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 830, in finalize_options
#         for ep in sorted(loaded, key=by_order):
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 829, in <lambda>
#         loaded = map(lambda e: e.load(), filtered)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2449, in load
#         self.require(*args, **kwargs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2472, in require
#         items = working_set.resolve(reqs, env, installer, extras=self.extras)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 772, in resolve
#         raise DistributionNotFound(req, requirers)
#     pkg_resources.DistributionNotFound: The 'tomli>=1.0.0' distribution was not found and is required by the application
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/da/86/370cccd7995df7a5593b05fcb4fea874ded1d7d174a2b919184e535706c2/word2number-0.1.zip#sha256=1b5960d25d7fb97927a1d8bfa9bd0e68e8390451dcfcf678b5a4081dd38638f3 (from https://pypi.org/simple/word2number/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting textattack
#   Using cached textattack-0.3.3-py3-none-any.whl (361 kB)
#   Using cached textattack-0.3.2-py3-none-any.whl (360 kB)
#   Using cached textattack-0.3.0-py3-none-any.whl (359 kB)
#   Using cached textattack-0.2.17-py3-none-any.whl (358 kB)
#   Using cached textattack-0.2.16-py3-none-any.whl (347 kB)
#   Using cached textattack-0.2.15-py3-none-any.whl (349 kB)
#   Using cached textattack-0.2.14-py3-none-any.whl (334 kB)
#   Using cached textattack-0.2.13-py3-none-any.whl (334 kB)
# Collecting tokenizers>=0.9.3
#   Using cached tokenizers-0.11.6-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
from https://pypi.org/simple/visdom/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached visdom-0.0.2.tar.gz (24 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /home/user/anaconda3/envs/NLP/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-jp4p7fpw/visdom_cc0a67de1b1a4520acc9a2f21b5553ee/setup.py'"'"'; __file__='"'"'/tmp/pip-install-jp4p7fpw/visdom_cc0a67de1b1a4520acc9a2f21b5553ee/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-y455xyif
#          cwd: /tmp/pip-install-jp4p7fpw/visdom_cc0a67de1b1a4520acc9a2f21b5553ee/
#     Complete output (21 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-jp4p7fpw/visdom_cc0a67de1b1a4520acc9a2f21b5553ee/setup.py", line 14, in <module>
#         setup(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/core.py", line 108, in setup
#         _setup_distribution = dist = klass(attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 453, in __init__
#         _Distribution.__init__(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/dist.py", line 292, in __init__
#         self.finalize_options()
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 830, in finalize_options
#         for ep in sorted(loaded, key=by_order):
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 829, in <lambda>
#         loaded = map(lambda e: e.load(), filtered)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2449, in load
#         self.require(*args, **kwargs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2472, in require
#         items = working_set.resolve(reqs, env, installer, extras=self.extras)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 772, in resolve
#         raise DistributionNotFound(req, requirers)
#     pkg_resources.DistributionNotFound: The 'tomli>=1.0.0' distribution was not found and is required by the application
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e8/3b/f4ccb3a12e8954a93cf364d5b0db59f954218d3c560b25eaed55d2e5dede/visdom-0.0.2.tar.gz#sha256=14e0dcfeb3ced396c81ef5777edaf8f6331fccd379264cd191b9a1bcd1ba047d (from https://pypi.org/simple/visdom/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached visdom-0.0.1.tar.gz (24 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /home/user/anaconda3/envs/NLP/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-jp4p7fpw/visdom_199f91e707e2489c9590e1d6fd6f382a/setup.py'"'"'; __file__='"'"'/tmp/pip-install-jp4p7fpw/visdom_199f91e707e2489c9590e1d6fd6f382a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-ex0qlsx4
#          cwd: /tmp/pip-install-jp4p7fpw/visdom_199f91e707e2489c9590e1d6fd6f382a/
#     Complete output (21 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-jp4p7fpw/visdom_199f91e707e2489c9590e1d6fd6f382a/setup.py", line 14, in <module>
#         setup(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/core.py", line 108, in setup
#         _setup_distribution = dist = klass(attrs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 453, in __init__
#         _Distribution.__init__(
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/distutils/dist.py", line 292, in __init__
#         self.finalize_options()
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 830, in finalize_options
#         for ep in sorted(loaded, key=by_order):
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/setuptools/dist.py", line 829, in <lambda>
#         loaded = map(lambda e: e.load(), filtered)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2449, in load
#         self.require(*args, **kwargs)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2472, in require
#         items = working_set.resolve(reqs, env, installer, extras=self.extras)
#       File "/home/user/anaconda3/envs/NLP/lib/python3.8/site-packages/pkg_resources/__init__.py", line 772, in resolve
#         raise DistributionNotFound(req, requirers)
#     pkg_resources.DistributionNotFound: The 'tomli>=1.0.0' distribution was not found and is required by the application
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/01/1e/a674de42cc497b3395c4d205bf74f8fba317426d9da792293d1788726a2d/visdom-0.0.1.tar.gz#sha256=30bff9f7ba02017923304a159e4e1383eae85d392c3720f76a66d2e291d9ac05 (from https://pypi.org/simple/visdom/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting textattack
#   Using cached textattack-0.2.10-py3-none-any.whl (214 kB)
# Collecting nlp
#   Downloading nlp-0.4.0-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 679 kB/s eta 0:00:01
# Collecting textattack
#   Using cached textattack-0.2.8-py3-none-any.whl (207 kB)
#   Using cached textattack-0.2.7-py3-none-any.whl (207 kB)
#   Using cached textattack-0.2.6-py3-none-any.whl (207 kB)
#   Using cached textattack-0.2.5-py3-none-any.whl (207 kB)
#   Using cached textattack-0.2.4-py3-none-any.whl (207 kB)
#   Using cached textattack-0.2.3-py3-none-any.whl (205 kB)
#   Using cached textattack-0.2.2-py3-none-any.whl (201 kB)
#   Using cached textattack-0.2.0-py3-none-any.whl (195 kB)
#   Using cached textattack-0.1.5-py3-none-any.whl (180 kB)
# Collecting transformers>=3
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 1.2 MB/s eta 0:00:01
# Collecting textattack
#   Using cached textattack-0.1.4-py3-none-any.whl (177 kB)
#   Using cached textattack-0.1.3-py3-none-any.whl (177 kB)
#   Using cached textattack-0.1.2-py3-none-any.whl (162 kB)
#   Using cached textattack-0.1.1-py3-none-any.whl (161 kB)
#   Using cached textattack-0.1.0-py3-none-any.whl (161 kB)
#   Using cached textattack-0.0.3.1-py3-none-any.whl (147 kB)
#   Using cached textattack-0.0.3.0-py3-none-any.whl (147 kB)
#   Using cached textattack-0.0.2.6-py3-none-any.whl (140 kB)
#   Using cached textattack-0.0.2.5-py3-none-any.whl (139 kB)
#   Using cached textattack-0.0.2.4-py3-none-any.whl (130 kB)
#   Using cached textattack-0.0.2.3-py3-none-any.whl (148 kB)
#   Using cached textattack-0.0.2.2-py3-none-any.whl (152 kB)
#   Using cached textattack-0.0.2.1-py3-none-any.whl (152 kB)
#   Using cached textattack-0.0.2.0-py3-none-any.whl (152 kB)
#   Using cached textattack-0.0.1.9-py3-none-any.whl (141 kB)
#   Using cached textattack-0.0.1.7-py3-none-any.whl (113 kB)
# Requirement already satisfied: tqdm in /home/user/anaconda3/envs/NLP/lib/python3.8/site-packages (from textattack) (4.64.0)
# Collecting language-tool-python
#   Downloading language_tool_python-2.7.0-py3-none-any.whl (34 kB)
# Collecting tensorflow-hub
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 655 kB/s eta 0:00:01
# ERROR: Cannot install textattack==0.0.1.7, textattack==0.0.1.9, textattack==0.0.2.0, textattack==0.0.2.1, textattack==0.0.2.2, textattack==0.0.2.3, textattack==0.0.2.4, textattack==0.0.2.5, textattack==0.0.2.6, textattack==0.0.3.0, textattack==0.0.3.1, textattack==0.1.0, textattack==0.1.1, textattack==0.1.2, textattack==0.1.3, textattack==0.1.4, textattack==0.1.5, textattack==0.2.0, textattack==0.2.10, textattack==0.2.11, textattack==0.2.12, textattack==0.2.13, textattack==0.2.14, textattack==0.2.15, textattack==0.2.16, textattack==0.2.17, textattack==0.2.2, textattack==0.2.3, textattack==0.2.4, textattack==0.2.5, textattack==0.2.6, textattack==0.2.7, textattack==0.2.8, textattack==0.3.0, textattack==0.3.2, textattack==0.3.3 and textattack==0.3.4 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     textattack 0.3.4 depends on word2number
#     textattack 0.3.3 depends on word2number
#     textattack 0.3.2 depends on word2number
#     textattack 0.3.0 depends on word2number
#     textattack 0.2.17 depends on word2number
#     textattack 0.2.16 depends on word2number
#     textattack 0.2.15 depends on word2number
#     textattack 0.2.14 depends on word2number
#     textattack 0.2.13 depends on word2number
#     textattack 0.2.12 depends on word2number
#     textattack 0.2.11 depends on visdom
#     textattack 0.2.10 depends on visdom
#     textattack 0.2.8 depends on visdom
#     textattack 0.2.7 depends on visdom
#     textattack 0.2.6 depends on visdom
#     textattack 0.2.5 depends on visdom
#     textattack 0.2.4 depends on visdom
#     textattack 0.2.3 depends on visdom
#     textattack 0.2.2 depends on visdom
#     textattack 0.2.0 depends on visdom
#     textattack 0.1.5 depends on visdom
#     textattack 0.1.4 depends on visdom
#     textattack 0.1.3 depends on visdom
#     textattack 0.1.2 depends on visdom
#     textattack 0.1.1 depends on visdom
#     textattack 0.1.0 depends on visdom
#     textattack 0.0.3.1 depends on visdom
#     textattack 0.0.3.0 depends on visdom
#     textattack 0.0.2.6 depends on visdom
#     textattack 0.0.2.5 depends on visdom
#     textattack 0.0.2.4 depends on visdom
#     textattack 0.0.2.3 depends on visdom
#     textattack 0.0.2.2 depends on visdom
#     textattack 0.0.2.1 depends on visdom
#     textattack 0.0.2.0 depends on visdom
#     textattack 0.0.1.9 depends on visdom
#     textattack 0.0.1.7 depends on visdom
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/user_guide/#fixing-conflicting-dependencies

# %%
# !python -m pip install textattack>=0.0.2

# %%
from textattack.augmentation import WordNetAugmenter
text = "start each day with positive thoughts and make your day"
wordnet_aug = WordNetAugmenter()
wordnet_aug.augment(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 from textattack.augmentation import WordNetAugmenter
#       2 text = "start each day with positive thoughts and make your day"
#       3 wordnet_aug = WordNetAugmenter()
#
# ModuleNotFoundError: No module named 'textattack'
